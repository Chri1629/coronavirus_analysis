# %% [markdown]
# # Studia la diffusione del corona virus.
#
# Basato sul lavoro e sulle funzioni create nel [seguente lavoro](https://github.com/jianxu305/nCov2019_analysis/)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import utils
# Out:
# ./STFANGSO.TTF not found.  If you wish to display Chinese characters in plots, please use set_font() to set the path to the font file.

# %%
data = utils.load_chinese_data()
# Out:
# Last update:  2020-02-27 18:15:29.337000
# Data date range:  2020-01-24 to 2020-02-27
# Number of rows in raw data:  57571

# %%
data.head(10)
# Out:
#   province_name provinceEnglishName  province_zipCode city_name  \
# 0           湖北省               Hubei            420000        武汉
# 1           湖北省               Hubei            420000        孝感
# 2           湖北省               Hubei            420000        黄冈
# 3           湖北省               Hubei            420000        鄂州
# 4           湖北省               Hubei            420000        荆州
# 5           湖北省               Hubei            420000        随州
# 6           湖北省               Hubei            420000        宜昌
# 7           湖北省               Hubei            420000        襄阳
# 8           湖北省               Hubei            420000        荆门
# 9           湖北省               Hubei            420000        黄石
#
#   cityEnglishName  city_zipCode  province_confirmed  province_suspected  \
# 0           Wuhan      420100.0               65596                   0
# 1         Xiaogan      420900.0               65596                   0
# ...

# %%
daily_frm = utils.aggDaily(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-79fccd7d46f2> in <module>
# ----> 1 daily_frm = utils.aggDaily(data)
#
# ~/Scrivania/progetti/coronavirus_analysis/utils.py in aggDaily(df)
#      77     #out = remove_abnormal_dates(out)
#      78     out = add_daily_new(out)  # add daily new cases
# ---> 79     out = add_en_location(out)
#      80     #out = out.set_index(['update_date'])
#      81
#
# ~/Scrivania/progetti/coronavirus_analysis/utils.py in add_en_location(df)
#     231 def add_en_location(df):
#     232     '''Add province_name_en, and city_name_en'''
# --> 233     chn_en = pd.read_csv(_CHN_EN_DICT_, encoding='utf-8')
#     234     translation = dict([t for t in zip(chn_en['Chinese'], chn_en['English'])])
#     235     df['province_name_en'] = df['province_name'].replace(translation)
#
# ...
